# %%
# ! pip install scrublet

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import scanpy.external as sce
import sys
import scipy

# %%
adata = sc.read_h5ad('calu3.h5ad')

# %%
adata.var_names_make_unique()

# %%
adata.obs['cell_type'].unique()
# Out:
# ['cultured cell']
# Categories (1, object): ['cultured cell']

# %%
adata.obs.head(2)
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# Calu3-S1-12h-A_AAAACGAAGCTG  Calu3-S1-12h-A      1399.0          1001
# Calu3-S1-12h-A_AAAACGTGTGTT  Calu3-S1-12h-A      2580.0          1425
#
#                                infect    strain  nCount_Unspliced  \
# Calu3-S1-12h-A_AAAACGAAGCTG  infected  SARSCoV1            1176.0
# Calu3-S1-12h-A_AAAACGTGTGTT  infected  SARSCoV1            2082.0
#
#                              nFeature_Unspliced  n_genes_by_counts  \
# Calu3-S1-12h-A_AAAACGAAGCTG                 861               1001
# Calu3-S1-12h-A_AAAACGTGTGTT                1216               1425
#
#                              log1p_n_genes_by_counts  total_counts  ...  \
# Calu3-S1-12h-A_AAAACGAAGCTG                 6.909753   2265.772705  ...
# Calu3-S1-12h-A_AAAACGTGTGTT                 7.262629   2597.423340  ...
#
#                              donor_id  suspension_type      cell_type  \
# Calu3-S1-12h-A_AAAACGAAGCTG    Calu-3             cell  cultured cell
# Calu3-S1-12h-A_AAAACGTGTGTT    Calu-3             cell  cultured cell
#
#                                 assay                            disease  \
# Calu3-S1-12h-A_AAAACGAAGCTG  Drop-seq  severe acute respiratory syndrome
# Calu3-S1-12h-A_AAAACGTGTGTT  Drop-seq  severe acute respiratory syndrome
#
#                                  organism   sex  \
# Calu3-S1-12h-A_AAAACGAAGCTG  Homo sapiens  male
# Calu3-S1-12h-A_AAAACGTGTGTT  Homo sapiens  male
#
#                                                              tissue  \
# Calu3-S1-12h-A_AAAACGAAGCTG  epithelial cell of lung (cell culture)
# Calu3-S1-12h-A_AAAACGTGTGTT  epithelial cell of lung (cell culture)
#
#                             self_reported_ethnicity development_stage
# Calu3-S1-12h-A_AAAACGAAGCTG                 unknown           unknown
# Calu3-S1-12h-A_AAAACGTGTGTT                 unknown           unknown
#
# [2 rows x 36 columns]

# %%
adata.var.head(2)
# Out:
#                  feature_is_filtered feature_name feature_reference  \
# feature_id
# ENSG00000146038                False        DCDC2    NCBITaxon:9606
# ENSG00000136536                False      MARCHF7    NCBITaxon:9606
#
#                 feature_biotype
# feature_id
# ENSG00000146038            gene
# ENSG00000136536            gene

# %% [markdown]
# ## select s2 only

# %%
adata = adata[adata.obs["strain"] != "SARSCoV1"]
adata = adata[adata.obs.query("strain != 'SARSCoV1'").index]
adata = adata[[r != "SARSCoV1" for r in adata.obs.strain]]
adata.obs.strain.unique()
# Out:
# ['nan', 'SARSCoV2']
# Categories (2, object): ['SARSCoV2', 'nan']

# %%
conditions = []
for i in range(len(adata.obs.index)):
    conditions.append(adata.obs.index[i].split('-')[1:3])
set(tuple(row) for row in conditions)
# Out:
# {('S2', '12h'), ('S2', '4h'), ('S2', '8h'), ('mock', '12h'), ('mock', '4h')}

# %% [markdown]
# ## retrieve raw counts

# %%
adata.X = adata.raw.X

# %% [markdown]
# ## create count matrix

# %%
#genes = list(adata.var['feature_name'].values)
#counts = adata[:, adata.var['feature_name'].isin(genes)].to_df()

# %%
sc.tl.pca(adata) 
sc.pl.pca(adata, frameon=False)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %%
sc.pl.pca(adata, color=["cell_type"], components = ['1,2','2,3','1,3','1,4','2,4','3,4'], ncols=3)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs.head(2)
# Out:
#                                      orig.ident  nCount_RNA  nFeature_RNA  \
# Calu3-mock-12h-A_AAAAATCCCTAG  Calu3-mock-12h-A      1467.0          1050
# Calu3-mock-12h-A_AAAACATACTTA  Calu3-mock-12h-A      1905.0          1271
#
#                               infect strain  nCount_Unspliced  \
# Calu3-mock-12h-A_AAAAATCCCTAG  uninf    nan            1269.0
# Calu3-mock-12h-A_AAAACATACTTA  uninf    nan            1592.0
#
#                                nFeature_Unspliced  n_genes_by_counts  \
# Calu3-mock-12h-A_AAAAATCCCTAG                 931               1050
# Calu3-mock-12h-A_AAAACATACTTA                1117               1271
#
#                                log1p_n_genes_by_counts  total_counts  ...  \
# Calu3-mock-12h-A_AAAAATCCCTAG                 6.957497   2334.701416  ...
# Calu3-mock-12h-A_AAAACATACTTA                 7.148346   2568.509033  ...
#
#                                donor_id  suspension_type      cell_type  \
# Calu3-mock-12h-A_AAAAATCCCTAG    Calu-3             cell  cultured cell
# Calu3-mock-12h-A_AAAACATACTTA    Calu-3             cell  cultured cell
#
#                                   assay  disease      organism   sex  \
# Calu3-mock-12h-A_AAAAATCCCTAG  Drop-seq   normal  Homo sapiens  male
# Calu3-mock-12h-A_AAAACATACTTA  Drop-seq   normal  Homo sapiens  male
#
#                                                                tissue  \
# Calu3-mock-12h-A_AAAAATCCCTAG  epithelial cell of lung (cell culture)
# Calu3-mock-12h-A_AAAACATACTTA  epithelial cell of lung (cell culture)
#
#                               self_reported_ethnicity development_stage
# Calu3-mock-12h-A_AAAAATCCCTAG                 unknown           unknown
# Calu3-mock-12h-A_AAAACATACTTA                 unknown           unknown
#
# [2 rows x 36 columns]

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(10, 4))
sc.pl.umap(adata, frameon=False, ax=axs[0], color=["cell_type"], title="UMAP", show=False) # Отрисовываем UMAP
sc.pl.tsne(adata, frameon=False, ax=axs[1], color=["cell_type"], title="t-SNE", show=False) # Отрисовываем t-SNE
# Out:
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <AxesSubplot: title={'center': 't-SNE'}, xlabel='tSNE1', ylabel='tSNE2'>

# %%
adata.obs['condition'] = adata.obs.index.str.split('-').str[1]
adata.obs['hpi'] = adata.obs.index.map(lambda x: x.split('-')[2].strip().replace("h","") if len(x.split('-'))>1 else None)

# %%
adata.obs
# Out:
#                                      orig.ident  nCount_RNA  nFeature_RNA  \
# Calu3-mock-12h-A_AAAAATCCCTAG  Calu3-mock-12h-A      1467.0          1050
# Calu3-mock-12h-A_AAAACATACTTA  Calu3-mock-12h-A      1905.0          1271
# Calu3-mock-12h-A_AAAACATGTCAA  Calu3-mock-12h-A      2156.0          1403
# Calu3-mock-12h-A_AAAACCAGACTA  Calu3-mock-12h-A      3418.0          2063
# Calu3-mock-12h-A_AAAACTCTAGCG  Calu3-mock-12h-A      2311.0          1378
# ...                                         ...         ...           ...
# Calu3-mock-4h-B_TTTTCGTTTGTG    Calu3-mock-4h-B      3873.0          1901
# Calu3-mock-4h-B_TTTTGGAATGGT    Calu3-mock-4h-B     54939.0          7926
# Calu3-mock-4h-B_TTTTGGCACGAC    Calu3-mock-4h-B     41645.0          7619
# Calu3-mock-4h-B_TTTTTGCGATAA    Calu3-mock-4h-B      2291.0          1322
# Calu3-mock-4h-B_TTTTTGGACGGC    Calu3-mock-4h-B     32295.0          6910
#
#                                  infect strain  nCount_Unspliced  \
# Calu3-mock-12h-A_AAAAATCCCTAG     uninf    nan            1269.0
# Calu3-mock-12h-A_AAAACATACTTA     uninf    nan            1592.0
# Calu3-mock-12h-A_AAAACATGTCAA     uninf    nan            1808.0
# Calu3-mock-12h-A_AAAACCAGACTA     uninf    nan            2507.0
# Calu3-mock-12h-A_AAAACTCTAGCG     uninf    nan            1889.0
# ...                                 ...    ...               ...
# Calu3-mock-4h-B_TTTTCGTTTGTG   infected    nan            3108.0
# Calu3-mock-4h-B_TTTTGGAATGGT   infected    nan           15378.0
# Calu3-mock-4h-B_TTTTGGCACGAC   infected    nan           14697.0
# Calu3-mock-4h-B_TTTTTGCGATAA   infected    nan            1891.0
# Calu3-mock-4h-B_TTTTTGGACGGC   infected    nan           13688.0
#
#                                nFeature_Unspliced  n_genes_by_counts  \
# Calu3-mock-12h-A_AAAAATCCCTAG                 931               1050
# Calu3-mock-12h-A_AAAACATACTTA                1117               1271
# Calu3-mock-12h-A_AAAACATGTCAA                1239               1403
# Calu3-mock-12h-A_AAAACCAGACTA                1650               2063
# Calu3-mock-12h-A_AAAACTCTAGCG                1210               1378
# ...                                           ...                ...
# Calu3-mock-4h-B_TTTTCGTTTGTG                 1671               1901
# Calu3-mock-4h-B_TTTTGGAATGGT                 4863               7926
# Calu3-mock-4h-B_TTTTGGCACGAC                 5007               7619
# Calu3-mock-4h-B_TTTTTGCGATAA                 1177               1322
# Calu3-mock-4h-B_TTTTTGGACGGC                 4800               6910
#
#                                log1p_n_genes_by_counts  total_counts  ...  \
# Calu3-mock-12h-A_AAAAATCCCTAG                 6.957497   2334.701416  ...
# Calu3-mock-12h-A_AAAACATACTTA                 7.148346   2568.509033  ...
# Calu3-mock-12h-A_AAAACATGTCAA                 7.247081   2725.995361  ...
# Calu3-mock-12h-A_AAAACCAGACTA                 7.632401   3297.717041  ...
# Calu3-mock-12h-A_AAAACTCTAGCG                 7.229114   2618.069824  ...
# ...                                                ...           ...  ...
# Calu3-mock-4h-B_TTTTCGTTTGTG                  7.550661   3033.565186  ...
# Calu3-mock-4h-B_TTTTGGAATGGT                  8.978030   4629.885254  ...
# Calu3-mock-4h-B_TTTTGGCACGAC                  8.938532   4656.414062  ...
# Calu3-mock-4h-B_TTTTTGCGATAA                  7.187657   2588.040527  ...
# Calu3-mock-4h-B_TTTTTGGACGGC                  8.840870   4659.293945  ...
#
#                                    cell_type     assay  disease      organism  \
# Calu3-mock-12h-A_AAAAATCCCTAG  cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-12h-A_AAAACATACTTA  cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-12h-A_AAAACATGTCAA  cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-12h-A_AAAACCAGACTA  cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-12h-A_AAAACTCTAGCG  cultured cell  Drop-seq   normal  Homo sapiens
# ...                                      ...       ...      ...           ...
# Calu3-mock-4h-B_TTTTCGTTTGTG   cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-4h-B_TTTTGGAATGGT   cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-4h-B_TTTTGGCACGAC   cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-4h-B_TTTTTGCGATAA   cultured cell  Drop-seq   normal  Homo sapiens
# Calu3-mock-4h-B_TTTTTGGACGGC   cultured cell  Drop-seq   normal  Homo sapiens
#
#                                 sex                                  tissue  \
# Calu3-mock-12h-A_AAAAATCCCTAG  male  epithelial cell of lung (cell culture)
# Calu3-mock-12h-A_AAAACATACTTA  male  epithelial cell of lung (cell culture)
# Calu3-mock-12h-A_AAAACATGTCAA  male  epithelial cell of lung (cell culture)
# Calu3-mock-12h-A_AAAACCAGACTA  male  epithelial cell of lung (cell culture)
# Calu3-mock-12h-A_AAAACTCTAGCG  male  epithelial cell of lung (cell culture)
# ...                             ...                                     ...
# Calu3-mock-4h-B_TTTTCGTTTGTG   male  epithelial cell of lung (cell culture)
# Calu3-mock-4h-B_TTTTGGAATGGT   male  epithelial cell of lung (cell culture)
# Calu3-mock-4h-B_TTTTGGCACGAC   male  epithelial cell of lung (cell culture)
# Calu3-mock-4h-B_TTTTTGCGATAA   male  epithelial cell of lung (cell culture)
# Calu3-mock-4h-B_TTTTTGGACGGC   male  epithelial cell of lung (cell culture)
#
#                               self_reported_ethnicity development_stage  \
# Calu3-mock-12h-A_AAAAATCCCTAG                 unknown           unknown
# Calu3-mock-12h-A_AAAACATACTTA                 unknown           unknown
# Calu3-mock-12h-A_AAAACATGTCAA                 unknown           unknown
# Calu3-mock-12h-A_AAAACCAGACTA                 unknown           unknown
# Calu3-mock-12h-A_AAAACTCTAGCG                 unknown           unknown
# ...                                               ...               ...
# Calu3-mock-4h-B_TTTTCGTTTGTG                  unknown           unknown
# Calu3-mock-4h-B_TTTTGGAATGGT                  unknown           unknown
# Calu3-mock-4h-B_TTTTGGCACGAC                  unknown           unknown
# Calu3-mock-4h-B_TTTTTGCGATAA                  unknown           unknown
# Calu3-mock-4h-B_TTTTTGGACGGC                  unknown           unknown
#
#                               condition hpi
# Calu3-mock-12h-A_AAAAATCCCTAG      mock  12
# Calu3-mock-12h-A_AAAACATACTTA      mock  12
# Calu3-mock-12h-A_AAAACATGTCAA      mock  12
# Calu3-mock-12h-A_AAAACCAGACTA      mock  12
# Calu3-mock-12h-A_AAAACTCTAGCG      mock  12
# ...                                 ...  ..
# Calu3-mock-4h-B_TTTTCGTTTGTG       mock   4
# Calu3-mock-4h-B_TTTTGGAATGGT       mock   4
# Calu3-mock-4h-B_TTTTGGCACGAC       mock   4
# Calu3-mock-4h-B_TTTTTGCGATAA       mock   4
# Calu3-mock-4h-B_TTTTTGGACGGC       mock   4
#
# [32755 rows x 38 columns]

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(10, 4))
sc.pl.umap(adata, frameon=False, ax=axs[0], color=["hpi"], title="UMAP", show=False) # Отрисовываем UMAP
sc.pl.tsne(adata, frameon=False, ax=axs[1], color=["hpi"], title="t-SNE", show=False) # Отрисовываем t-SNE
# Out:
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <AxesSubplot: title={'center': 't-SNE'}, xlabel='tSNE1', ylabel='tSNE2'>

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(10, 4))

sc.pl.umap(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[0], color=["condition"], title="UMAP", show=False) # Отрисовываем UMAP
sc.pl.tsne(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[1], color=["condition"], title="t-SNE", show=False) # Отрисовываем t-SNE
# Out:
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <AxesSubplot: title={'center': 't-SNE'}, xlabel='tSNE1', ylabel='tSNE2'>

# %%
#sc.pl.pca(adata, color=["condition"], components = ['1,2','2,3','1,3','1,4','2,4','3,4'], ncols=3)

# %%
#sc.pl.pca(adata, color=["hpi"], components = ['1,2','2,3','1,3','1,4','2,4','3,4'], ncols=3)

# %%
#sc.pl.pca(adata[adata.obs['hpi'] == '12'], color=["condition"], components = ['1,2','2,3','1,3','1,4','2,4','3,4'], ncols=3)

# %%
fig, axs = plt.subplots(ncols=2, nrows=3, figsize=(5, 6))

sc.pl.umap(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 0], color=["condition"], title="UMAP (hpi=4)", show=False) 
sc.pl.tsne(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 1], color=["condition"], title="t-SNE (hpi=4)", show=False)

sc.pl.umap(adata[adata.obs['hpi'] == '8'], frameon=False, ax=axs[1, 0], color=["condition"], title="UMAP (hpi=8)", show=False)
sc.pl.tsne(adata[adata.obs['hpi'] == '8'], frameon=False, ax=axs[1, 1], color=["condition"], title="t-SNE (hpi=8)", show=False)

sc.pl.umap(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[2, 0], color=["condition"], title="UMAP (hpi=12)", show=False) 
sc.pl.tsne(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[2, 1], color=["condition"], title="t-SNE (hpi=12)", show=False)

plt.tight_layout()
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fig, axs = plt.subplots(ncols=2, nrows=3, figsize=(10, 12))

sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 0],  components = ['1,2'], color=["condition"], title=" PC 1 and 2 (hpi=4)", show=False) 
sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 1],  components = ['2,3'], color=["condition"], title=" PC 2 and 3  (hpi=4)", show=False)

sc.pl.pca(adata[adata.obs['hpi'] == '8'], frameon=False, ax=axs[1, 0],  components = ['1,2'], color=["condition"], title="PC 1 and 2  (hpi=8)", show=False)
sc.pl.pca(adata[adata.obs['hpi'] == '8'], frameon=False, ax=axs[1, 1],  components = ['2,3'], color=["condition"], title="PC 2 and 3  (hpi=8)", show=False)

sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[2, 0],  components = ['1,2'], color=["condition"], title="PC 1 and 2  (hpi=12)", show=False) 
sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[2, 1],  components = ['2,3'], color=["condition"], title="PC 2 and 3  (hpi=12)", show=False)

plt.tight_layout()
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(10, 12))
sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 0],  components = ['1,2'], color=["condition"], title=" PC 1 and 2 (hpi=4)", show=False) 
sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 1],  components = ['2,3'], color=["condition"], title=" PC 2 and 3  (hpi=4)", show=False)
sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[1, 0],  components = ['1,2'], color=["condition"], title="PC 1 and 2  (hpi=12)", show=False)
sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[1, 1],  components = ['2,3'], color=["condition"], title="PC 2 and 3  (hpi=12)", show=False)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <AxesSubplot: title={'center': 'PC 2 and 3  (hpi=12)'}, xlabel='PC2', ylabel='PC3'>

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(8, 4))

sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0],  components = ['1,2'], color=["condition"], title=" PC 1 and 2 (hpi=4)", show=False) 
sc.pl.pca(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[1],  components = ['2,3'], color=["condition"], title=" PC 2 and 3  (hpi=4)", show=False)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /opt/homebrew/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# /opt/homebrew/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <AxesSubplot: title={'center': ' PC 2 and 3  (hpi=4)'}, xlabel='PC2', ylabel='PC3'>

# %%
import scanpy as sc
import matplotlib.pyplot as plt

gene = 'ENSG00000154451'
# define the figure and axes objects
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(8, 4))

# plot the first subplot
pca_12 = sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[0],  components = ['1,2'], color=[gene], title=" PC 1 and 2 (hpi=12), Var. ratio = {:.2f}".format(adata.uns['pca']['variance_ratio'][0]), show=False) 

# plot the second subplot
pca_23 = sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[1],  components = ['2,3'], color=[gene], title=" PC 2 and 3 (hpi=12), Var. ratio = {:.2f}".format(adata.uns['pca']['variance_ratio'][1]), show=False)

# add a main title for the entire plot
fig.suptitle("PCA plot for hpi=12")
# Out:
# Text(0.5, 0.98, 'PCA plot for hpi=12')

# %%
# plot the elbow plot
sc.pl.pca_variance_ratio(adata[adata.obs['hpi'] == '4'], log=True)

# %%
enr8  = pd.read_csv('/Users/sofialuk/Desktop/thesis/Calu3/calu3_GSEA/enr_GOBP_down_8.csv')
enr8.head(2)
# Out:
#    Unnamed: 0                    Gene_set  \
# 0           0  GO_Biological_Process_2021
# 1           1  GO_Biological_Process_2021
#
#                                         Term Overlap       P-value  \
# 0  defense response to symbiont (GO:0140546)  45/124  4.499043e-41
# 1     defense response to virus (GO:0051607)  46/133  7.556104e-41
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0      8.889756e-38            0                     0   25.397747
# 1      8.889756e-38            0                     0   23.619289
#
#    Combined Score                                              Genes
# 0     2359.504650  RTP4;IFITM1;IFIT5;NLRC5;IFIT1;SAMHD1;IFI44L;IF...
# 1     2182.035748  RTP4;IFITM1;IFIT5;NLRC5;IFIT1;SAMHD1;IFI44L;IF...

# %%
enr8.Genes[1]
# Out:
# 'RTP4;IFITM1;IFIT5;NLRC5;IFIT1;SAMHD1;IFI44L;IFIT3;IFIT2;OASL;IFIH1;IFNL2;IFNL1;IFI16;TRIM5;PMAIP1;IFNL4;IFNL3;ZBP1;APOBEC3F;RSAD2;APOBEC3G;IFNB1;STAT1;MX2;STAT2;MX1;EIF2AK2;IFNLR1;ISG15;BST2;NT5C3A;CXCL10;MOV10;IL6;OAS1;OAS2;IFNE;IRF1;OAS3;IRF2;IRF7;SHFL;MYD88;TLR3;TRIM56'

# %%
adata.var.index
# Out:
# Index(['ENSG00000146038', 'ENSG00000136536', 'ENSG00000116679',
#        'ENSG00000160360', 'ENSG00000165282', 'ENSG00000023330',
#        'ENSG00000105371', 'ENSG00000171234', 'ENSG00000117242',
#        'ENSG00000258279',
#        ...
#        'ENSG00000137760', 'ENSG00000004534', 'ENSG00000025423',
#        'ENSG00000164543', 'ENSG00000073578', 'ENSG00000163596',
#        'ENSG00000224152', 'ENSG00000145388', 'ENSG00000038219',
#        'ENSG00000181513'],
#       dtype='object', name='feature_id', length=16210)

# %%
ens = adata.var.index
import mygene
mg = mygene.MyGeneInfo()
geneSyms = mg.querymany(ens, scopes='ensembl.gene') # annotate ensembl symbols
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-16210...done.
# Finished.
# 24 input query terms found no hit:
# 	['ENSG00000256222', 'ENSG00000204092', 'ENSG00000112096', 'ENSG00000225932', 'ENSG00000168078', 'ENS
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
genes = pd.DataFrame(geneSyms)

# %%
genes
# Out:
#                  query     _id     _score entrezgene  \
# 0      ENSG00000146038   51473  25.012510      51473
# 1      ENSG00000136536   64844  24.494726      64844
# 2      ENSG00000116679   10625  25.833334      10625
# 3      ENSG00000160360   26086  24.606480      26086
# 4      ENSG00000165282   84720  24.103474      84720
# ...                ...     ...        ...        ...
# 16205  ENSG00000163596  130026  25.833334     130026
# 16206  ENSG00000224152  643072  25.833334     643072
# 16207  ENSG00000145388   57721  23.523886      57721
# 16208  ENSG00000038219  259282  23.768686     259282
# 16209  ENSG00000181513   79777  25.140093      79777
#
#                                                     name     symbol   taxid  \
# 0                       doublecortin domain containing 2      DCDC2  9606.0
# 1              membrane associated ring-CH-type finger 7    MARCHF7  9606.0
# 2                   influenza virus NS1A binding protein   IVNS1ABP  9606.0
# 3                        G protein signaling modulator 1      GPSM1  9606.0
# 4      phosphatidylinositol glycan anchor biosynthesi...       PIGO  9606.0
# ...                                                  ...        ...     ...
# 16205                      islet cell autoantigen 1 like      ICA1L  9606.0
# 16206                              BAZ2B antisense RNA 1  BAZ2B-AS1  9606.0
# 16207  methyltransferase 14, N6-adenosine-methyltrans...    METTL14  9606.0
# 16208  biorientation of chromosomes in cell division ...     BOD1L1  9606.0
# 16209               acyl-CoA binding domain containing 4      ACBD4  9606.0
#
#       notfound
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 16205      NaN
# 16206      NaN
# 16207      NaN
# 16208      NaN
# 16209      NaN
#
# [16210 rows x 8 columns]

# %%
# Out:
# 0        ENSG00000146038
# 1        ENSG00000136536
# 2        ENSG00000116679
# 3        ENSG00000160360
# 4        ENSG00000165282
#               ...
# 16205    ENSG00000163596
# 16206    ENSG00000224152
# 16207    ENSG00000145388
# 16208    ENSG00000038219
# 16209    ENSG00000181513
# Name: query, Length: 16210, dtype: object

# %%
adata.var.index = genes['query']

# %%
adata.var.feature_name
# Out:
# query
# ENSG00000146038         DCDC2
# ENSG00000136536       MARCHF7
# ENSG00000116679      IVNS1ABP
# ENSG00000160360         GPSM1
# ENSG00000165282          PIGO
#                       ...
# ENSG00000163596         ICA1L
# ENSG00000224152    AC009506.1
# ENSG00000145388       METTL14
# ENSG00000038219        BOD1L1
# ENSG00000181513         ACBD4
# Name: feature_name, Length: 16210, dtype: category
# Categories (16210, object): ['A1BG', 'A1CF', 'A2M-AS1', 'A4GALT', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']

# %%
gene_list = enr8['Genes'][1].split(';')  # defense response to virus (GO:0051607) 

genes_str = ','.join(gene_list)
genes_list = genes_str.split(',')

# %%
pathway1 = adata.var[adata.var.feature_name.isin(genes_list)].index

# %%
import scanpy as sc
import matplotlib.pyplot as plt

gene = pathway1[10]
# define the figure and axes objects
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(8, 4))

# plot the first subplot
pca_12 = sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[0],  
                   components = ['1,2'], color=[gene], 
                   title=" PC 1 and 2 (hpi=12), Var. ratio = {:.2f}".format(adata.uns['pca']['variance_ratio'][0]),
                   show=False) 

# plot the second subplot
pca_23 = sc.pl.pca(adata[adata.obs['hpi'] == '12'], frameon=False, ax=axs[1],
                   components = ['2,3'], color=[gene], 
                   title=" PC 2 and 3 (hpi=12), Var. ratio = {:.2f}".format(adata.uns['pca']['variance_ratio'][1]),
                   show=False)

# add a main title for the entire plot
fig.suptitle("PCA plot for hpi=12")
print(genes_list[10])
# Out:
# IFIH1

# %%
adata[adata.obs['hpi'] == '12'].uns['pca']['variance_ratio'][0]
adata[adata.obs['hpi'] == '12'].uns['pca']['variance_ratio'][1]
# Out:
# 0.027090866

# %%
adata.var

# %%
fig, axs = plt.subplots(ncols=2, nrows=3, figsize=(5, 6))


sc.pl.umap(adata[adata.obs['hpi'] == '4'], frameon=False, ax=axs[0, 0], color=pathway1[1],
           title="UMAP hpi=4, gene = {}".format(genes_list[1]),
           show=False) 


sc.pl.tsne(adata[adata.obs['hpi'] == '4'],
           frameon=False, ax=axs[0, 1],
           color=pathway1[1],
           title="t-SNE hpi=4, gene = {}".format(genes_list[1]),
           show=False)

sc.pl.umap(adata[adata.obs['hpi'] == '8'],
           frameon=False, ax=axs[1, 0],
           color=pathway1[1],
           title="UMAP hpi=8, gene = {}".format(genes_list[1]),

           show=False)

sc.pl.tsne(adata[adata.obs['hpi'] == '8'],
           frameon=False, ax=axs[1, 1],
           color=pathway1[1],
           title="t-SNE hpi=8, gene = {}".format(genes_list[1]),

           show=False)

sc.pl.umap(adata[adata.obs['hpi'] == '12'],
           frameon=False, ax=axs[2, 0],
           color=pathway1[1],
           title="UMAP (hpi=12)",
           show=False) 

sc.pl.tsne(adata[adata.obs['hpi'] == '12'],
           frameon=False, ax=axs[2, 1],
           color=pathway1[1], 
           title="t-SNE hpi=12, gene = {}".format(genes_list[1]),

           show=False)

plt.tight_layout()
plt.show()
